# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter
import os

# Set the path to the file you'd like to load
file_path = "Healthcare.csv"

# The error message indicated that files are available at '/kaggle/input/healthcare-symptomsdisease-classification-dataset'
# Let's list the contents of that directory to find the correct file name.
dataset_dir = '/kaggle/input/healthcare-symptomsdisease-classification-dataset'
print(f"Files in the dataset directory '{dataset_dir}':")
for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        print(os.path.join(root, file))

# Load the latest version - temporarily commented out until the correct file name is identified.
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "kundanbedmutha/healthcare-symptomsdisease-classification-dataset",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# Files in the dataset directory '/kaggle/input/healthcare-symptomsdisease-classification-dataset':
# /kaggle/input/healthcare-symptomsdisease-classification-dataset/Healthcare.csv
# /tmp/ipython-input-138268716.py:19: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'healthcare-symptomsdisease-classification-dataset' dataset.
# First 5 records:    Patient_ID  Age  Gender                                           Symptoms  \
# 0           1   29    Male              fever, back pain, shortness of breath
# 1           2   76  Female                   insomnia, back pain, weight loss
# 2           3   78    Male                    sore throat, vomiting, diarrhea
# 3           4   58   Other  blurred vision, depression, weight loss, muscl...
# 4           5   55  Female                    swelling, appetite loss, nausea
#
# ...
